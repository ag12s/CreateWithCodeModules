# %% [markdown]
# <a href="https://colab.research.google.com/github/ag12s/CreateWithCodeModules/blob/main/Introduction%20to%20Python/Day1/A3.6-plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p style="text-align: center;"><font size="8"><b>Scetion 3.6: Plotting</b></font><br>

# %% [markdown]
# A nice feature of Python is the ease in which we can create graphics. For scientific applications the graphics we will mainly be interested in are related to data visualization.
#
# The standard package we will use is called `matplotlib`, specifically the `matplotlib.pyplot` submodule. This allows us to plot using similar syntax to Matlab (don't worry if this doens't mean anything to you).

# %% [markdown]
# To display plots in the notebook, we include the following directive at the top of the notebook (before the plots).

# %%
# %matplotlib inline

# %% [markdown]
# # Basic Plots
#
# Without further ado, let's start looking at some plots. First we'll import `matplotlib.pylot` module. To avoid lots of typing later on, we will call this module `plt`.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# The `plt.plot` command creates a plot.

# %%
plt.plot([1,2,4,3])
plt.show()

# %% [markdown]
# You'll note that the x-axis ranges from 0 to 3 while the y axis ranges from 1 to 4. If you provide a single list or array to the `plot` command `matlplotlib` assumes it is a sequence of y values and automatically generates the x values for you. The default x values start at 0 (the leading index for Python arrays) and has the same length as y. Therefore in this example x gets the values [0,1,2,3]. The plot above connects the points (0,1), (1,2), (1,4) and (1,3).

# %% [markdown]
# The plot command can take in an arbitrary number of arguments. For example if you have a specific set of x values you can input a list (or array) of x value in addition to the y values.

# %%
plt.plot([1,2,8,9], [1,2,4,3])
plt.show()

# %% [markdown]
# ## Exercise
#
# Plot the data:
#
# | x | y  |
# |---|----|
# | 1 | 50 |
# | 2 | 60 |
# | 4 | 40 |
# | 6 | 30 |
# | 10| 40 |

# %% [markdown]
# After the data, an optional argument to the plot command is a string which indicates the color and type of the plot. These letters and symbols of the string are identical to Matlab (again don't worry if you don't know anything about Matlab).

# %% [markdown]
# The color is specified by one of the following characters:
# * 'b' - blue (default)
# * 'r' - red
# * 'g' - green
# * 'c' - cyan
# * 'y' - yellow
# * 'm' - magenta
# * 'k' - black
# * 'w' - white

# %% [markdown]
# To plot the individual data points, you can specify one of the following characters:
# * 'o' - points plotted as circles
# * 's' - points plotted as squares
# * '^' - points plotted as triangles
# * '.' - points plotted as dots
#
# The line style can can be one given as one of:
# * '-'  - continuous line (default)
# * '--' - dashed line
# * ':'  - dotted line

# %% [markdown]
# For example to plot the data using red circles we would pass in "ro".

# %%
plt.plot([1,2,8,9], [1,2,4,3], "ro")
plt.show()

# %% [markdown]
# These plots are all well and good, but you may want to make them look better or easier to understand. For starters the last plot had some of the data points on the edges of the plot. There is a command called `xlim` that takes in a list of 2 numbers: a lower bound for x and an upper bound for x and sets the x axis to these values. The command `ylim` does the same thing for the y axis.

# %%
plt.plot([1,2,8,9], [1,2,4,3], "g^--")
plt.ylim([0,5])
plt.show()

# %% [markdown]
# All good plots should also have axis labels. The commands `xlabel` and `ylabel` do just that. The `title` command provides a title.

# %%
plt.plot([1,2,8,9], [1,2,4,3], "-ro")
plt.xlim([0,10])
plt.ylim([0,5])
plt.xlabel("x values")
plt.ylabel("y values")
plt.title("A simple plot")
plt.show()

# %% [markdown]
# Plots can also have legends. The command `plt.legend()` creates one. In Python there are two ways to populate them.
#
# 1. Pass an argument `label` to the plot command
# 2. Add a list of names directly to the `legend` command

# %%
plt.plot([1,2,8,9], [1,2,4,3], "-ro", label="red line with circles")
plt.xlim([0,10])
plt.ylim([0,5])
plt.xlabel("x values")
plt.ylabel("y values")
plt.title("A simple plot")
plt.legend()
plt.show()

# %%
plt.plot([1,2,8,9], [1,2,4,3], "-g^")
plt.xlim([0,10])
plt.ylim([0,5])
plt.xlabel("x values")
plt.ylabel("y values")
plt.title("A simple plot")
plt.legend(["green line with triangles"]) #this command takes in a list of names
plt.show()

# %% [markdown]
# ## Exercise
#
# Plot the data:
#
# | x | y  |
# |---|----|
# | 1 | 50 |
# | 2 | 60 |
# | 4 | 40 |
# | 6 | 30 |
# | 10| 40 |
#
# Color the data points with red triangles and connect them with dashed lines. Make the y-axis range from 20 to 80. Add a title and axis labels.

# %% [markdown]
# # Plotting Functions
#
# Say for example we wish to plot the function $y(t) = t^2e^{-t^2}$ for $0 \leq t\leq 3$. To do this we will generate a number of equally spaced coordinates in $t$. Then we can evaluate $y(t)$ at each of those points. To do this we will use the `linspace` command from the NumPy module.

# %%
import numpy as np # import the NumPy module

N = 20

# create N equally spaced points on the interval [0,3]
t = np.linspace(0,3,N)
print(t)
# Out:
# [0.         0.15789474 0.31578947 0.47368421 0.63157895 0.78947368
#  0.94736842 1.10526316 1.26315789 1.42105263 1.57894737 1.73684211
#  1.89473684 2.05263158 2.21052632 2.36842105 2.52631579 2.68421053
#  2.84210526 3.        ]

# %% [markdown]
# To evaluate the function $y(t)$ at all these points, we can plug this array into $y$.

# %%
y = t**2*np.exp(-t**2)
print(y)
# Out:
# [0.         0.02431689 0.09025809 0.17928016 0.26768172 0.33418978
#  0.36580994 0.36007615 0.32357053 0.2680465  0.20606616 0.14771311
#  0.09907603 0.06234629 0.03688445 0.02054842 0.01079419 0.00535239
#  0.00250749 0.00111069]

# %% [markdown]
# To plot $y$ vs $t$ we simply call `plot`:

# %%
plt.plot(t,y)
plt.xlabel("t")
plt.ylabel("y(t)")
plt.show()

# %% [markdown]
# Alternatively, we don't have to create y at all. The function equation can be evaluated directly in the argument list of the `plot` command

# %%
plt.plot(t, t**2*np.exp(-t**2))
plt.xlabel("t")
plt.ylabel("y(t)")
plt.show()

# %% [markdown]
# ## Exercise
#
# Plot the function $y = \sin(x)\cos(x)$ on the interval $0\leq x\leq 2\pi$.
#
# HINT: Use np.sin(array of numbers) and np.cos(array of numbers) or import math for sin and cos functions.

# %% [markdown]
# # Multiple Plots on the Same Figure
#
# Often we'll want multiple plots on the same figure. This can be done simply by calling successive plot commands. It should be noted that one can generate plots without specifying a color and matplotlib will choose from a default color sequence.

# %%
plt.plot(t, t**2*np.exp(-t**2), 'm-')
plt.plot([1,2,8,9], [0.1,0.2,0.4,0.3], "g^--")
plt.xlabel("t")
plt.ylabel("y(t)")
plt.legend(["function","points"])
plt.show()

# %% [markdown]
# ## Exercise
#
# Plot the functions $y=\sin(x)$ and $y=\cos(x)$ on the same plot on the interval $0\leq x\leq 2\pi$. Add a legend that indicates which is which.

# %% [markdown]
# # Scatter Plots
#
# Sometimes we may have a number of coordinate points that we wish to visualize, but not have lines connecting them. For instance, these points may be rainfall measurements over a specific region. Fortunately for us, `matplotlib` has many different plot generating functions beyong the simple `plot` command. One such function is `scatter` that is a little more adept at handling plotting unconnected data points than `plot`.
#
# An example would be call to the scatter-plotting function would be `plt.scatter(xpoints,ypoints,**kwargs)`, where `**kwargs` indicates a variable number of optional parameters one can specify.

# %%
x = np.random.random(100)
y = np.random.random(100)
plt.scatter(x, y**2*np.exp(-y**2))

plt.xlabel("t")
plt.ylabel("y(t)")
plt.title("A basic scatter plot of random data")
plt.show()

# %% [markdown]
# Some optional parameters for `scatter` include `c = an array of values` which will color code the indivdual scatter points based on the values given to `c`, or the parameter `alpha = some number` that controls the transparency of the scatter points. Additional useful parameters include `s = some number` for the size of the scatter points and `marker = some string character` for changing the style of scatter point used.
#
# Just like with adding data points to a simple `plot` figure, the `scatter` point styles examples include:
# * 'o' - points plotted as circles
# * 's' - points plotted as squares
# * '^' - points plotted as triangles
# * '.' - points plotted as dots
#
# However, there are wide variety of other symbols that can be chosen.

# %%
x = np.random.random(250)
y = np.random.random(250)
z = x**2 * np.exp(-y**2)
plt.scatter(y, z, color='r', marker='+')
plt.scatter(x, z, c=z, s=100.0, alpha=0.25)

plt.xlabel("t")
plt.ylabel("y(t)")
plt.title("Transparent colorful points on top of red crosses")
plt.show()

# %% [markdown]
# #Exercise
# Plot 100 random points evaluated using the function
# $$ z = x^5e^{-y^3}+5y$$
#
# Play around with the styles. Once you have a plot you are happy with, take a screenshot and post it [here](https://docs.google.com/presentation/d/1afKvTMUQ5TlyB0H31oq38cIRwpdsW_hExHmUb_GNVUA/edit?usp=sharing).

# %% [markdown]
# # Subplots
#
# Sometimes we wish to have multiple plots in a single figure. The `subplot` command lets us create a figure with $r$ rows and $c$ columns of plots.
#
# Calling `plt.subplot(r,c,p)` creates a figure (if it doesn't already exist) containing a tiling of $r$ rows of plots and $c$ columns. Any plotting commands you call will be placed in entry $p$. The plots are numbered from 1 to $r\times c$, starting in the top left and proceeding left to right and then top to bottom.
#
# To switch to another plot, simply call `plt.subplot` again with the new position.

# %%
plt.subplot(2,1,1)
plt.plot(t, t**2*np.exp(-t**2))
plt.title("Top plot")
plt.xlabel("t")
plt.ylabel("y(t)")

plt.subplot(2,1,2)
plt.plot([1,2,8,9], [1,2,4,3], "-ro")
plt.axis([0, 10, 0, 5])
plt.xlabel("x values")
plt.ylabel("y values")
plt.title("Bottom plot")

# should add this to get correct spacing between subplots
plt.tight_layout()

# %% [markdown]
# ## Exercise
#
# Create a 2x2 suplot with the following plots:
#
# 1. $y=\sin(x)$ for $0\leq x\leq 2\pi$
# 2. $y=\cos(x)$ for $0\leq x\leq 2\pi$
# 3. $y=\tan(x)$ for $0\leq x\leq 2\pi$
# 4. $y=\sin(x)+\cos(x)+\tan(x)$ for $0\leq x\leq 2\pi$
#
# Add titles and axis labels to all plots. Set the y-axis to range between -1.2 and 1.2 on all plots.

# %%
# create x values
x= np.linspace(0,2*np.pi,100)

# plot sin(x)
plt.subplot(2,2,1)

# plot cos(x)
plt.subplot(2,2,2)

# plot tan(x)
plt.subplot(2,2,3)

# plot sin(x) + cos(x) + tan(x)
plt.subplot(2,2,4)

plt.tight_layout()

# %% [markdown]
# #Skimage
#
# Skimage is a library which that contains image processing applications. We will use the `io` functions from it here to read images from a url.

# %%
from skimage import io

# %% [markdown]
# # Imread
#
# Scientific visualization may involve using existing digital images and performing manipulations or calculations using the data that represents these images. When one looks at an image, one is essentially looking at a table of values organized in rows and columns. These values describe how the pixels of the image should look like. For black and white images, these numbers merely represent the intensity of brightness of each pixel, giving darker/blacker and brighter/white regions with shades of grey in between. For color images, there will be a set of 4 numbers for each pixel: one for brightness and 3 for the values of red, green, blue (RGB) colors that are mixed together to create the specific color of that pixel.
#
# We can use a nifty function called `imread` from `io` in Skimage to obtain the table of values for an image with `io.imread(string name to image location)`. In the code example below, we read in the data that represents the image we pointed the function to. The size of the resulting Tuple object corresponds to the (height, width, number of channels). If the number of channels is three, our image has RGB values.

# %%
image = io.imread("https://github.com/ag12s/CreateWithCodeModules/blob/main/images/binary.jpg?raw=True")
print(image.shape)
# Out:
# (362, 528, 3)

# %% [markdown]
# # Imshow
#
# We now have the image data from `imread`, but what about re-visualizing the image? We can use the `imshow` command from `plt` for that exact purpose!
#
# The easiest thing to do is simply `plt.imshow(table of data)` to reveal the image whose data we previously read with `plt.imread()`

# %%
plt.imshow(image)
plt.show()
